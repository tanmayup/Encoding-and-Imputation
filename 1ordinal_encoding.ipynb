# %%
import pandas as pd
import numpy as np

# %%
def ord_enc(data: dict, heirarchy: dict, column: str):
    df = pd.DataFrame(data)
    df[f"{column} Order"] = df[column].map(heirarchy)
    return df

# %%
data = {
    "Name": ["Tanmay", "Vivek", "Saurabh", "Raghav", "Rounak", "Rohan"],
    "State": ["UP", "RJ", "RJ", "HR", "BR", "RJ"]
}

column = "Education"

# %%
education_heirarchy = {
    "High School": 1,
    "Bachelors": 2,
    "Masters": 3,
    "PhD": 4
}

# %%
print(ord_enc(data, education_heirarchy, column))
# Out:
#       Name    Education  Education Order
# 0   Tanmay    Bachelors                2
# 1    Vivek      Masters                3
# 2    Rohan  High School                1
# 3   Raghav          PhD                4
# 4   Rounak    Bachelors                2
# 5  Aaditya      Masters                3
